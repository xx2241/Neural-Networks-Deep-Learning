# %% [markdown]
# ### Example for using function load_data and printing dataset

# %%
from hw3_utils import load_data
#downsample the training and validation dataset if needed, ds_rate should be larger than 1.
ds_rate=None
datasets = load_data(ds_rate=ds_rate,theano_shared=False)
train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]
print('Current training data size is %i'%train_set_x.shape[0])
print('Current validation data size is %i'%valid_set_x.shape[0])
print('Current test data size is %i'%test_set_x.shape[0])
# Out:
# Current training data size is 40000
# Current validation data size is 10000
# Current test data size is 10000
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
class_=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#Choose an image index
i=15
plt.imshow(np.reshape(valid_set_x[i],(3,32,32)).transpose(1,2,0))
plt.xticks([])
plt.yticks([])
plt.title('Original picture')
plt.xlabel('%s'%class_[valid_set_y[i]])
# Out:
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# # ECBM E6040 Homework 3 - Programming Problem

# %% [markdown]
# ### Problem 1: Implement the convolutional neural network depicted in this problem

# %%
import hw3
from hw3 import test_lenet
test_lenet()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 80/80, validation error 65.510000 %
#      epoch 1, minibatch 80/80, test error of best model 64.960000 %
# training @ iter =  100
# epoch 2, minibatch 80/80, validation error 62.810000 %
#      epoch 2, minibatch 80/80, test error of best model 62.900000 %
# training @ iter =  200
# epoch 3, minibatch 80/80, validation error 54.430000 %
#      epoch 3, minibatch 80/80, test error of best model 54.680000 %
# training @ iter =  300
# epoch 4, minibatch 80/80, validation error 53.210000 %
# ...

# %% [markdown]
# ### The setting of CNN in problem 1 is just the structure and parameter provided in the homework 3 PDF file.

# %% [markdown]
# ### Problem 2: Bullet 1: Augmentation by translation

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
from hw3 import translate_image
#downsample the training and validation dataset if needed, ds_rate should be larger than 1.
ds_rate=None
datasets = load_data(ds_rate=ds_rate,theano_shared=False)
train_set_x, train_set_y = datasets[0]
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
class_=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#Choose an image index
plt.figure(figsize = (4, 4))
for i in range(16):
    temp = translate_image(train_set_x[1000*i:1000*(i+1)],4)
    tempy = train_set_y[1000*i:1000*(i+1)]
    plt.subplot(4, 4, i+1)
    img = (np.reshape(temp[i],(3,32,32))).transpose(1,2,0)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel('%s'%class_[tempy[i]])

# %% [markdown]
# ### As shown in the pictures above, the pictures will shift randomly or not shift

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_translation
import hw3_utils
test_lenet_translation()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ('training @ iter = ', 0)
# epoch 1, minibatch 80/80, validation error 67.070000 %
#      epoch 1, minibatch 80/80, test error of best model 66.460000 %
# ('training @ iter = ', 100)
# epoch 2, minibatch 80/80, validation error 61.060000 %
#      epoch 2, minibatch 80/80, test error of best model 60.720000 %
# ('training @ iter = ', 200)
# epoch 3, minibatch 80/80, validation error 52.820000 %
#      epoch 3, minibatch 80/80, test error of best model 52.990000 %
# ('training @ iter = ', 300)
# epoch 4, minibatch 80/80, validation error 49.770000 %
# ...

# %%
from hw3 import test_lenet_translation
import hw3_utils
test_lenet_translation()
# Out:
# ... building the model
# ('training @ iter = ', 0)
# epoch 1, minibatch 80/80, validation error 64.720000 %
#      epoch 1, minibatch 80/80, test error of best model 64.160000 %
# ('training @ iter = ', 100)
# epoch 2, minibatch 80/80, validation error 58.420000 %
#      epoch 2, minibatch 80/80, test error of best model 58.870000 %
# ('training @ iter = ', 200)
# epoch 3, minibatch 80/80, validation error 55.920000 %
#      epoch 3, minibatch 80/80, test error of best model 55.440000 %
# ('training @ iter = ', 300)
# epoch 4, minibatch 80/80, validation error 53.430000 %
#      epoch 4, minibatch 80/80, test error of best model 52.930000 %
# epoch 5, minibatch 80/80, validation error 50.920000 %
#      epoch 5, minibatch 80/80, test error of best model 51.070000 %
# ('training @ iter = ', 400)
# epoch 6, minibatch 80/80, validation error 47.970000 %
#      epoch 6, minibatch 80/80, test error of best model 47.760000 %
# ('training @ iter = ', 500)
# ...

# %% [markdown]
# ### I add a random shift of 1 pixels either horizontally or vertically or the both, or not shift. I update the random translation at the start of each epoch. However, the result is not as good as the result in problem 1. I compare my results with others and find out that my results in problem 1 is better than others, most people get a result of 32% or 33% of error rate in problem 1. Since we all use the same structure and parameter in problem 1, it seems like I get a great result in problem 1 coincidently and make training in problem 2 hard to beat it.  The structure in problem 1 is not perfect and SGD and can't converge fast can also be the reason.

# %% [markdown]
# ### Problem 2: Bullet 2: Augmentation by rotation

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
from hw3 import rotate_image
#downsample the training and validation dataset if needed, ds_rate should be larger than 1.
ds_rate=None
datasets = load_data(ds_rate=ds_rate,theano_shared=False)
train_set_x, train_set_y = datasets[0]
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
class_=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#Choose an image index
plt.figure(figsize = (4, 4))
for i in range(16):
    temp = rotate_image(train_set_x[1000*i:1000*(i+1)],15)
    tempy = train_set_y[1000*i:1000*(i+1)]
    plt.subplot(4, 4, i+1)
    img = (np.reshape(temp[i],(3,32,32))).transpose(1,2,0)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel('%s'%class_[tempy[i]])
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_rotation
test_lenet_rotation()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ('training @ iter = ', 0)
# epoch 1, minibatch 80/80, validation error 64.340000 %
#      epoch 1, minibatch 80/80, test error of best model 63.900000 %
# ('training @ iter = ', 100)
# epoch 2, minibatch 80/80, validation error 63.100000 %
#      epoch 2, minibatch 80/80, test error of best model 63.220000 %
# ('training @ iter = ', 200)
# epoch 3, minibatch 80/80, validation error 55.850000 %
#      epoch 3, minibatch 80/80, test error of best model 55.770000 %
# ('training @ iter = ', 300)
# epoch 4, minibatch 80/80, validation error 51.440000 %
# ...

# %% [markdown]
# ### I chose -10 degree to 10 degree of rotation and the result is not so good. It seems like 10 degree noise is too much. When I set it down to -4 to 4 degree in problem 3 it works fine.

# %% [markdown]
# ### Problem 2: Bullet 3: Augmentation by flipping

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
from hw3 import flip_image
#downsample the training and validation dataset if needed, ds_rate should be larger than 1.
ds_rate=None
datasets = load_data(ds_rate=ds_rate,theano_shared=False)
train_set_x, train_set_y = datasets[0]
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
class_=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#Choose an image index
plt.figure(figsize = (4, 4))
for i in range(16):
    temp = flip_image(train_set_x[1000*i:1000*(i+1)])
    tempy = train_set_y[1000*i:1000*(i+1)]
    plt.subplot(4, 4, i+1)
    img = (np.reshape(temp[i],(3,32,32))).transpose(1,2,0)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel('%s'%class_[tempy[i]])
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# ### As shown in the picture above, it will randomly flip or not flip the picture horizontally.

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_flip
test_lenet_flip()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ('training @ iter = ', 0)
# epoch 1, minibatch 80/80, validation error 65.800000 %
#      epoch 1, minibatch 80/80, test error of best model 65.380000 %
# ('training @ iter = ', 100)
# epoch 2, minibatch 80/80, validation error 60.260000 %
#      epoch 2, minibatch 80/80, test error of best model 60.380000 %
# ('training @ iter = ', 200)
# epoch 3, minibatch 80/80, validation error 58.900000 %
#      epoch 3, minibatch 80/80, test error of best model 59.160000 %
# ('training @ iter = ', 300)
# epoch 4, minibatch 80/80, validation error 52.060000 %
# ...

# %% [markdown]
# ### However, since I use vertical flip at the begining and it is just before the deadline when I discovered that I should use horizontal flip, so I set the patience to 4000 in order to meet the deadline. Although I don't have time to run the whole 10000 iteration, I can see that the result with flip converge fast and it perform better than the other augmentation methods even for just 4000 iterations. I think that is because it doesn't add extra noise to the image and simply expand the numbers of training set. Although noise might be good for data augmentation, since lenet is very primitive, it cannot deal with too much noise.

# %% [markdown]
# ### Problem 2: Bullet 4: Augmentation by injecting noise into input

# %% [markdown]
# Show a 4*4 figure of 16 input images with this augmentation

# %%
from hw3_utils import load_data
from hw3 import noise_injection
#downsample the training and validation dataset if needed, ds_rate should be larger than 1.
ds_rate=None
datasets = load_data(ds_rate=ds_rate,theano_shared=False)
train_set_x, train_set_y = datasets[0]
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
class_=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#Choose an image index
plt.figure(figsize = (4, 4))
for i in range(16):
    temp = noise_injection(train_set_x[1000*i:1000*(i+1)],0.05)
    tempy = train_set_y[1000*i:1000*(i+1)]
    plt.subplot(4, 4, i+1)
    img = (np.reshape(temp[i],(3,32,32))).transpose(1,2,0)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel('%s'%class_[tempy[i]])
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %% [markdown]
# ### As shown in the picture. It will randomly add Gaussian-distributed and uniformly-distributed noise with zero mean or not adding noise. Also the instruction said that we should write a switch between this two noise distribution, but I this it is better to generate noise randomly and can chose the scale of noise.

# %% [markdown]
# Implement the neural network with this augmentation, show the improvement

# %%
from hw3 import test_lenet_inject_noise_input
test_lenet_inject_noise_input()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ('training @ iter = ', 0)
# epoch 1, minibatch 80/80, validation error 63.790000 %
#      epoch 1, minibatch 80/80, test error of best model 62.990000 %
# ('training @ iter = ', 100)
# epoch 2, minibatch 80/80, validation error 58.610000 %
#      epoch 2, minibatch 80/80, test error of best model 58.450000 %
# ('training @ iter = ', 200)
# epoch 3, minibatch 80/80, validation error 54.960000 %
#      epoch 3, minibatch 80/80, test error of best model 54.470000 %
# ('training @ iter = ', 300)
# epoch 4, minibatch 80/80, validation error 57.590000 %
# ...

# %% [markdown]
# ### I set the scale of noise to 0.01. The error rate is below 32%. Although it is still not as good as my result in problem 1, compared to other classmates's results in problem 1 it still has some improve.

# %% [markdown]
# ### Problem 3: Implement your own achritecture to achieve at least 80% testing accuracy on CIFAR-10 test set

# %%
from hw3 import MY_lenet
MY_lenet()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ... training
# ('training @ iter = ', 0)
# epoch 1, minibatch 80/80, validation error 75.660000 %
#      epoch 1, minibatch 80/80, test error of best model 75.510000 %
# ('training @ iter = ', 100)
# epoch 2, minibatch 80/80, validation error 61.130000 %
#      epoch 2, minibatch 80/80, test error of best model 61.390000 %
# ('training @ iter = ', 200)
# epoch 3, minibatch 80/80, validation error 54.210000 %
#      epoch 3, minibatch 80/80, test error of best model 53.280000 %
# ('training @ iter = ', 300)
# epoch 4, minibatch 80/80, validation error 45.870000 %
# ...

# %% [markdown]
# ### In problem 3, the structure I chose is according to the lecture in stanford cs231n, with a basic structure as Conv-Conv-Maxpooling-Conv-Conv-Maxpooling-Conv-Conv-Maxpooling. The kernel size of convlayer I chose is two 32\*3\*3 followed by two 64\*3\*3 followed by two 128\*3\*3. After this structure, I add two dropout hiddenlayers, I set p=0.5. I also use relu as my activation function, adam as my learning algorithm (https://gist.github.com/skaae/ae7225263ca8806868cb) is my reference for the code of adam function).
# ### Since my structure has a very fast rate of convergence, I can view the improve of performance by just running a few epoch and then stop it manually. After trying for many different methods, I can perform a 22%-23% accuracy training only 30-40 epoch without data augmentation.
# ### For data augmentation, since my results in problem 2 is not so good, I modified the parameter of data augmentation lower. I set the scale of noise to 0.006, scale of rotation to 4 degree, and the scale of translation to -1 or 1 pixel. I put the data augmentation updates before every mini_batch in order to further increase its randomness. I don't put flip in the data augmentation because at first I flip vertically for problem 2 and the result turned really bad. When I discovered that I should flip horizonally the homework deadline is coming so I don't have time to experiment with it. Ironically, horizontal flip turned out to be the best data augmentation method according to result in problem 2.
# ### After modified my structure and parameters, I train this layer with 200 epoch. The result is shown in the above cell. It converge very fast in the first 50 epoch and already reach 21% of validation error. Then it converge slowly from 21% validation error to 20% validation error, but obviously the results is still turning good when it reach 200 epoch. With the frist 200 epoch, the best validation error is 20.23% with the corresponding test error of 21.61%. If I have the chance to add horizontal flip or have more time to train this nerual network I think the error rate will be better.

# %% [markdown]
# ### Problem 4: Implement the convolutional neural network depicted in this problem

# %%
from hw3 import MY_CNN
import numpy as np
import matplotlib.pyplot as plt
dataset = MY_CNN()
origin_test_set = dataset[0]
corrupt_test_set = dataset[1]
restored_test_set = dataset[2]
# %matplotlib inline
plt.figure(figsize = (8, 1))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(np.reshape(origin_test_set[i],(3,32,32)).transpose(1,2,0))
    plt.xticks([])
    plt.yticks([])
    plt.title('Original')
plt.figure(figsize = (8, 1))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(np.reshape(corrupt_test_set[i],(3,32,32)).transpose(1,2,0))
    plt.xticks([])
    plt.yticks([])
    plt.title('Corrupted')
plt.figure(figsize = (8, 1))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(np.reshape(restored_test_set[i],(3,32,32)).transpose(1,2,0))
    plt.xticks([])
    plt.yticks([])
    plt.title('Restored')
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ... training
# ('training @ iter = ', 0)
# ('training @ iter = ', 100)
# epoch 1, minibatch 133/133, validation error 0.468380
#      epoch 1, minibatch 133/133, test error of best model 0.470144
# ('training @ iter = ', 200)
# epoch 2, minibatch 133/133, validation error 0.281554
#      epoch 2, minibatch 133/133, test error of best model 0.283429
# ('training @ iter = ', 300)
# epoch 3, minibatch 133/133, validation error 0.225129
#      epoch 3, minibatch 133/133, test error of best model 0.226821
# ('training @ iter = ', 400)
# ('training @ iter = ', 500)
# ...

# %%
from hw3 import MY_CNN
import numpy as np
import matplotlib.pyplot as plt
dataset = MY_CNN()
origin_test_set = dataset[0]
corrupt_test_set = dataset[1]
restored_test_set = dataset[2]
# %matplotlib inline
plt.figure(figsize = (8, 1))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(np.reshape(origin_test_set[i],(3,32,32)).transpose(1,2,0))
    plt.xticks([])
    plt.yticks([])
    plt.title('Original')
plt.figure(figsize = (8, 1))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(np.reshape(corrupt_test_set[i],(3,32,32)).transpose(1,2,0))
    plt.xticks([])
    plt.yticks([])
    plt.title('Corrupted')
plt.figure(figsize = (8, 1))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(np.reshape(restored_test_set[i],(3,32,32)).transpose(1,2,0))
    plt.xticks([])
    plt.yticks([])
    plt.title('Restored')
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# ... training
# ('training @ iter = ', 0)
# ('training @ iter = ', 100)
# epoch 1, minibatch 133/133, validation error 0.458046
#      epoch 1, minibatch 133/133, test error of best model 0.459262
# ('training @ iter = ', 200)
# epoch 2, minibatch 133/133, validation error 0.280905
#      epoch 2, minibatch 133/133, test error of best model 0.282145
# ('training @ iter = ', 300)
# epoch 3, minibatch 133/133, validation error 0.214137
#      epoch 3, minibatch 133/133, test error of best model 0.215157
# ('training @ iter = ', 400)
# ('training @ iter = ', 500)
# ...

# %% [markdown]
# ### As we can see from the cells above, the converge speed is fast and the test error can be reduced to below 0.03.
# ### We can campare the result of the two cells above. In the first cell I run for only 2000 iterations. Although the result is ok, but the detail is still not great enough, i.e., the color is slightly lighter and there are still three dropped pixels in the last frog picture. In the second cell I run for 5300 iterations and the error reduced to below 0.03. The restored picture is almost the same as the origin pictures.
